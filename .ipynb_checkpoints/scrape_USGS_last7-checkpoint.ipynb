# %%
import csv
import requests
from BeautifulSoup import BeautifulSoup

# %%
base_url='https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson'

# %%
# print base_url
# Out:
# https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson

# %%
response=requests.get(base_url)
results=response.json()

# %%
print results['features'][1]
# Out:
# {u'geometry': {u'type': u'Point', u'coordinates': [-116.6886667, 33.6281667, 7.81]}, u'type': u'Feature', u'properties': {u'rms': 0.25, u'code': u'38017024', u'cdi': None, u'sources': u',ci,', u'nst': 18, u'tz': -480, u'title': u'M 0.3 - 8km N of Anza, CA', u'magType': u'ml', u'detail': u'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci38017024.geojson', u'sig': 1, u'net': u'ci', u'type': u'earthquake', u'status': u'automatic', u'updated': 1506966150997, u'felt': None, u'alert': None, u'dmin': 0.07461, u'mag': 0.28, u'gap': 58, u'types': u',geoserve,nearby-cities,origin,phase-data,scitech-link,', u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/ci38017024', u'ids': u',ci38017024,', u'tsunami': 0, u'place': u'8km N of Anza, CA', u'time': 1506965937200, u'mmi': None}, u'id': u'ci38017024'}

# %%
print results['features'][10]['geometry']['coordinates']
# Out:
# [-142.9837, 67.1697, 0]

# %%
all_data=[]
all_data.append(['lat','long','url','magnitude','depth','places','time'])

# %%
for i in results['features']:
    row=[]
    row.append(i['geometry']['coordinates'][1])
    row.append(i['geometry']['coordinates'][0])
    row.append(i['properties']['url'])
    row.append(i['properties']['mag'])
    row.append(i['geometry']['coordinates'][2])
    row.append(i['properties']['place'])
    row.append(i['properties']['time'])
#     print i['properties']['time']
    
#     row.append(time)
    
    all_data.append(row)

# %%
print all_data
# Out:
# [['lat', 'long', 'url', 'magnitude', 'depth', 'places', 'time'], [37.238, -115.4783, u'https://earthquake.usgs.gov/earthquakes/eventpage/nn00607868', 1.1, 7, u'31km WSW of Alamo, Nevada', 1506966403870], [33.6281667, -116.6886667, u'https://earthquake.usgs.gov/earthquakes/eventpage/ci38017024', 0.28, 7.81, u'8km N of Anza, CA', 1506965937200], [37.4553337, -118.8301697, u'https://earthquake.usgs.gov/earthquakes/eventpage/nc72903196', 1.54, 2.33, u'24km SSE of Mammoth Lakes, California', 1506963756000], [37.4546661, -118.8306656, u'https://earthquake.usgs.gov/earthquakes/eventpage/nc72903176', 1.44, 2.12, u'24km SSE of Mammoth Lakes, California', 1506962394140], [33.4245, -116.4148333, u'https://earthquake.usgs.gov/earthquakes/eventpage/ci38016944', 0.87, 13.09, u'19km N of Borrego Springs, CA', 1506961979110], [37.4550018, -118.8270035, u'https://earthquake.usgs.gov/earthquakes/eventpage/nc72903166', 1.93, 2.15, u'25km SSE of Mammoth Lakes, California', 1506961834070], [37.4544983, -118.8266678, u'https://earthquake.usgs.gov/earthquakes/eventpage/nc72903156', 1.79, 1.72, u'25km SSE of Mammoth Lakes, California', 1506961396610], [37.4543343, -118.8280029, u'https://earthquake.usgs.gov/earthquakes/eventpage/nc72903146', 3.05, 3.03, u'25km SSE of Mammoth Lakes, California', 1506961086750], [37.5853348, -118.9455032, u'https://earthquake.usgs.gov/earthquakes/eventpage/nc72903141', 1.07, -0.27, u'7km SSE of Mammoth Lakes, California', 1506960555530], [33.8736667, -117.0343333, u'https://earthquake.usgs.gov/earthquakes/eventpage/ci38016888', 1.27, 0.23, u'8km SW of Beaumont, CA', 1506960224920], [67.1697, -142.9837, u'https://earthquake.usgs.gov/earthquakes/eventpage/ak16988071', 1.4, 0, u'120km NE of Fort Yukon, Alaska', 1506959208997], [36.5559, -113.8425, u'https://earthquake.usgs.gov/earthquakes/eventpage/nn00607854', 1.7, 8.1, u'34km SE of Mesquite, Nevada', 1506958960926], [38.7944984, -122.7543335, u'https://earthquake.usgs.gov/earthquakes/eventpage/nc72903126', 0.86, 0.63, u'1km N of The Geysers, California', 1506958266200], [36.5505, -89.8025, u'https://earthquake.usgs.gov/earthquakes/eventpage/nm60207666', 2.19, 12.47, u'14km E of Malden, Missouri', 1506957159610], [61.2492, -146.8151, u'https://earthquake.usgs.gov/earthquakes/eventpage/ak16988065', 2.7, 19.9, u'28km WNW of Valdez, Alaska', 1506956391417], [2.6798, 127.1289, u'https://earthquake.usgs.gov/earthquakes/eventpage/us2000axtv', 4.7, 25.66, u'143km NW of Tobelo, Indonesia', 1506953290020], [64.6409, -149.2609, u'https://earthquake.usgs.gov/earthquakes/eventpage/ak16987055', 1.1, 14.4, u'9km NW of North Nenana, Alaska', 1506952513029], [38.8165016, -122.7853317, u'https://earthquake.usgs.gov/earthquakes/eventpage/nc72903091', 0.52, 1.96, u'5km W of Cobb, California', 1506951699890], [38.8328323, -122.7516632, u'https://earthquake.usgs.gov/earthquakes/eventpage/nc72903081', 1.18, 0.68, u'2km WNW of Cobb, California', 1506950851670], [28.6895, 51.6372, u'https://earthquake.usgs.gov/earthquakes/eventpage/us2000axtl', 4.7, 10, u'76km SSE of Borazjan, Iran', 1506950716850], [44.7795, -111.084, u'https://earthquake.usgs.gov/earthquakes/eventpage/uu60250902', 1.34, 11.23, u'13km N of West Yellowstone, Montana', 1506949268120], [19.4743328, -155.6031647, u'https://earthquake.usgs.gov/earthquakes/eventpage/hv61929981', 2.46, 1.02, u'27km E of Honaunau-Napoopoo, Hawaii', 1506948942600], [36.2851, -97.5037, u'https://earthquake.usgs.gov/earthquakes/eventpage/us2000axsh', 2.6, 3.93, u'19km W of Perry, Oklahoma', 1506947996150], [38.4975, -118.2635, u'https://earthquake.usgs.gov/earthquakes/eventpage/nn00607859', 0.3, 8.5, u'31km E of Hawthorne, Nevada', 1506947449624], [63.1205, -151.1189, u'https://earthquake.usgs.gov/earthquakes/eventpage/ak16987046', 1.5, 16.2, u'102km NNW of Talkeetna, Alaska', 1506947130357], [36.3171654, -120.8834991, u'https://earthquake.usgs.gov/earthquakes/eventpage/nc72903071', 1.4, 6.77, u'24km ENE of King City, California', 1506946592080], [13.209 ...

# %%
file = open("./USGS_last_7_days_2.csv","wb")
writer = csv.writer(file)
writer.writerows(all_data)
